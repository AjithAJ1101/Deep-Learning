# %% [markdown]
# <h2 style="color:blue" align="center">Handwritten digits classification using ANN</h2>

# %% [markdown]
# In this notebook we will classify handwritten digits using a simple neural network (ANN) first and than repeat same thing with convolutional neural network. We will see how accuracy improves clickly when you use convolutional neural network.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(X_train, y_train) , (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_test.shape
# Out:
# (10000, 28, 28)

# %%
X_train[0].shape
# Out:
# (28, 28)

# %%
plt.matshow(X_train[0])

# %%
y_train[0]
# Out:
# 5

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
X_train_flattened = X_train.reshape(len(X_train), 28*28)
X_test_flattened = X_test.reshape(len(X_test), 28*28)

# %%
X_train_flattened.shape
# Out:
# (60000, 784)

# %% [markdown]
# # <h3 style='color:purple'>Using ANN for classification</h3>

# %%
model = model = keras.Sequential([
    keras.layers.Dense(100, input_shape=(784,), activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_flattened, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 17s 7ms/step - loss: 0.2777 - accuracy: 0.9198
# Epoch 2/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.1249 - accuracy: 0.9628
# Epoch 3/5
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0881 - accuracy: 0.9733
# Epoch 4/5
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0670 - accuracy: 0.9796
# Epoch 5/5
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0533 - accuracy: 0.9834

# %%
y_train[:5]
# Out:
# array([5, 0, 4, 1, 9], dtype=uint8)

# %%
model.evaluate(X_test_flattened,y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0822 - accuracy: 0.9750
# [0.08223055303096771, 0.9750000238418579]

# %% [markdown]
# # Callbacks

# %%
from tensorflow.keras.callbacks import Callback, CSVLogger, EarlyStopping, LearningRateScheduler, ModelCheckpoint, ReduceLROnPlateau,LambdaCallback

# %% [markdown]
# # CSV logger

# %%
model = model = keras.Sequential([
    keras.layers.Dense(100, input_shape=(784,), activation='relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
checkpoint = CSVLogger('./logs.csv', separator=';', append=True)

# %%
model.fit(X_train_flattened, y_train, epochs=50, batch_size=128, validation_data=(X_test_flattened,y_test), callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 469/469 [==============================] - 9s 15ms/step - loss: 0.3786 - accuracy: 0.8956 - val_loss: 0.2015 - val_accuracy: 0.9435
# Epoch 2/50
# 469/469 [==============================] - 6s 12ms/step - loss: 0.1775 - accuracy: 0.9493 - val_loss: 0.1543 - val_accuracy: 0.9558
# Epoch 3/50
# 469/469 [==============================] - 6s 14ms/step - loss: 0.1314 - accuracy: 0.9618 - val_loss: 0.1214 - val_accuracy: 0.9636
# Epoch 4/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1019 - accuracy: 0.9697 - val_loss: 0.1041 - val_accuracy: 0.9689
# Epoch 5/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0842 - accuracy: 0.9758 - val_loss: 0.0994 - val_accuracy: 0.9704
# Epoch 6/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0710 - accuracy: 0.9792 - val_loss: 0.0898 - val_accuracy: 0.9722
# Epoch 7/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0610 - accuracy: 0.9822 - val_loss: 0.0854 - val_accuracy: 0.9740
# Epoch 8/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0520 - accuracy: 0.9850 - val_loss: 0.0835 - val_accuracy: 0.9751
# Epoch 9/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0454 - accuracy: 0.9870 - val_loss: 0.0804 - val_accuracy: 0.9772
# Epoch 10/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0391 - accuracy: 0.9890 - val_loss: 0.0776 - val_accuracy: 0.9763
# Epoch 11/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0338 - accuracy: 0.9907 - val_loss: 0.0803 - val_accuracy: 0.9770
# Epoch 12/50
# 469/469 [==============================] - 6s 13ms/step - loss: 0.0300 - accuracy: 0.9923 - val_loss: 0.0765 - val_accuracy: 0.9764
# Epoch 13/50
# 469/469 [==============================] - 5s 12ms/step - loss: 0.0262 - accuracy: 0.9933 - val_loss: 0.0771 - val_accuracy: 0.9766
# Epoch 14/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0226 - accuracy: 0.9944 - val_loss: 0.0781 - val_accuracy: 0.9767
# Epoch 15/50
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0209 - accuracy: 0.9946 - val_loss: 0.0815 - val_accuracy: 0.9774
# Epoch 16/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0178 - accuracy: 0.9960 - val_loss: 0.0805 - val_accuracy: 0.9774
# Epoch 17/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0146 - accuracy: 0.9970 - val_loss: 0.0825 - val_accuracy: 0.9767
# Epoch 18/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0132 - accuracy: 0.9973 - val_loss: 0.0814 - val_accuracy: 0.9776
# Epoch 19/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0117 - accuracy: 0.9976 - val_loss: 0.0848 - val_accuracy: 0.9776
# Epoch 20/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0111 - accuracy: 0.9977 - val_loss: 0.0888 - val_accuracy: 0.9762
# Epoch 21/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0090 - accuracy: 0.9984 - val_loss: 0.0895 - val_accuracy: 0.9775
# Epoch 22/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0078 - accuracy: 0.9988 - val_loss: 0.0912 - val_accuracy: 0.9770
# Epoch 23/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0074 - accuracy: 0.9986 - val_loss: 0.0870 - val_accuracy: 0.9785
# Epoch 24/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0061 - accuracy: 0.9991 - val_loss: 0.0910 - val_accuracy: 0.9769
# Epoch 25/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0067 - accuracy: 0.9987 - val_loss: 0.0899 - val_accuracy: 0.9780
# Epoch 26/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0043 - accuracy: 0.9995 - val_loss: 0.0921 - val_accuracy: 0.9775
# Epoch 27/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.1009 - val_accuracy: 0.9782
# Epoch 28/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0040 - accuracy: 0.9994 - val_loss: 0.0960 - val_accuracy: 0.9786
# Epoch 29/50
# 469/469 [==============================] - 6s 12ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.1057 - val_accuracy: 0.9760
# Epoch 30/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 0.0982 - val_accuracy: 0.9777
# Epoch 31/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0041 - accuracy: 0.9993 - val_loss: 0.1005 - val_accuracy: 0.9776
# Epoch 32/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.0983 - val_accuracy: 0.9788
# Epoch 33/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1003 - val_accuracy: 0.9797
# Epoch 34/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.1185 - val_accuracy: 0.9760
# Epoch 35/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0096 - accuracy: 0.9969 - val_loss: 0.1141 - val_accuracy: 0.9770
# Epoch 36/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 0.1090 - val_accuracy: 0.9778
# Epoch 37/50
# 469/469 [==============================] - 5s 10ms/step - loss: 9.5938e-04 - accuracy: 0.9999 - val_loss: 0.1072 - val_accuracy: 0.9788
# Epoch 38/50
# 469/469 [==============================] - 5s 10ms/step - loss: 6.4191e-04 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 0.9782
# Epoch 39/50
# 469/469 [==============================] - 5s 10ms/step - loss: 5.4695e-04 - accuracy: 1.0000 - val_loss: 0.1074 - val_accuracy: 0.9786
# Epoch 40/50
# 469/469 [==============================] - 5s 11ms/step - loss: 4.8605e-04 - accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9785
# Epoch 41/50
# 469/469 [==============================] - 5s 10ms/step - loss: 4.3743e-04 - accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9788
# Epoch 42/50
# 469/469 [==============================] - 5s 11ms/step - loss: 5.0225e-04 - accuracy: 1.0000 - val_loss: 0.1123 - val_accuracy: 0.9787
# Epoch 43/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0109 - accuracy: 0.9963 - val_loss: 0.1260 - val_accuracy: 0.9762
# Epoch 44/50
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.1160 - val_accuracy: 0.9781
# Epoch 45/50
# 469/469 [==============================] - 5s 10ms/step - loss: 7.3672e-04 - accuracy: 1.0000 - val_loss: 0.1137 - val_accuracy: 0.9786
# Epoch 46/50
# 469/469 [==============================] - 5s 10ms/step - loss: 4.2161e-04 - accuracy: 1.0000 - val_loss: 0.1162 - val_accuracy: 0.9785
# Epoch 47/50
# 469/469 [==============================] - 5s 10ms/step - loss: 3.3781e-04 - accuracy: 1.0000 - val_loss: 0.1161 - val_accuracy: 0.9788
# Epoch 48/50
# 469/469 [==============================] - 5s 10ms/step - loss: 2.9472e-04 - accuracy: 1.0000 - val_loss: 0.1158 - val_accuracy: 0.9784
# Epoch 49/50
# 469/469 [==============================] - 5s 11ms/step - loss: 2.6262e-04 - accuracy: 1.0000 - val_loss: 0.1175 - val_accuracy: 0.9788
# Epoch 50/50
# 469/469 [==============================] - 5s 10ms/step - loss: 2.3782e-04 - accuracy: 1.0000 - val_loss: 0.1198 - val_accuracy: 0.9789

# %%
# accuracy on validation set

model.evaluate(X_test_flattened,y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1104 - accuracy: 0.9796
# [0.11035005748271942, 0.9796000123023987]
